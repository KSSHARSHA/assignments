# %% [markdown]
# # ASSIGNMENT - 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy.random import randn , randint , uniform, sample

# %%
data = sns.load_dataset('fmri')
data.head(5)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %%
data.describe()
# Out:
#          timepoint       signal
# count  1064.000000  1064.000000
# mean      9.000000     0.003540
# std       5.479801     0.093930
# min       0.000000    -0.255486
# 25%       4.000000    -0.046070
# 50%       9.000000    -0.013653
# 75%      14.000000     0.024293
# max      18.000000     0.564985

# %% [markdown]
# # RELPLOT with Two Variables

# %%
sns.relplot(x='timepoint',y='signal',data=data)

# %% [markdown]
# # RELPLOT with 3 variables

# %%
sns.relplot(x='timepoint',y='signal',data=data,hue='event')

# %% [markdown]
# # RELPLOT with 4 variables

# %%
sns.relplot(x='timepoint',y='signal',data=data,hue='event',style='region')

# %% [markdown]
# # LINEPLOT with 2 variables

# %%
sns.lineplot(x='timepoint',y='signal',data=data)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# # LINEPLOT with 3 variables

# %%
sns.lineplot(x='timepoint',y='signal',data=data,hue='event')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# # LINEPLOT with 4 variables

# %%
sns.lineplot(x='timepoint',y='signal',data=data,hue='event',style='region')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# # BOXPLOT with 2 variables

# %%
sns.boxplot(x='timepoint',y='signal',data=data)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# # BOXPLOT with 3 variables

# %%
sns.boxplot(x='timepoint',y='signal',data=data,hue='event')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>
